# %%
import pandas as pd

# %%
df = pd.read_json("plants.json")
df.head()
# Out:
#    plant_id                name  temperature  \
# 0         1       Venus flytrap    14.377395
# 1         2       Corpse flower    14.061050
# 2         3  Rafflesia arnoldii    16.078470
# 3         4    Black bat flower    16.341454
# 4         5       Pitcher plant    17.032140
#
#                                      origin_location  \
# 0  {'latitude': 43.74, 'longitude': -11.5098, 'ci...
# 1  {'latitude': 47.8428, 'longitude': -48.7087, '...
# 2  {'latitude': -25.4878, 'longitude': -36.1349, ...
# 3  {'latitude': 63.3661, 'longitude': 46.4049, 'c...
# 4  {'latitude': 82.8917, 'longitude': 0.6279, 'ci...
#
#                                             botanist  \
# 0  {'name': 'Kenneth Buckridge', 'email': 'kennet...
# 1  {'name': 'Ms. Diana King', 'email': 'ms..diana...
# 2  {'name': 'Eduardo Okuneva II', 'email': 'eduar...
# 3  {'name': 'Wilson Welch', 'email': 'wilson.welc...
# 4  {'name': 'Benny Block', 'email': 'benny.block@...
#
#                last_watered  soil_moisture           recording_taken  \
# 0  2025-09-22T13:51:41.000Z      29.214005  2025-09-23T09:42:04.069Z
# 1  2025-09-22T14:58:34.000Z      33.845243  2025-09-23T09:42:05.697Z
# 2  2025-09-22T13:58:19.000Z      35.075470  2025-09-23T09:42:06.436Z
# 3  2025-09-22T14:56:07.000Z      35.718464  2025-09-23T09:42:06.894Z
# 4  2025-09-22T13:57:08.000Z      33.613691  2025-09-23T09:42:07.737Z
#
#                                               images         scientific_name
# 0                                                NaN                     NaN
# 1                                                NaN                     NaN
# 2                                                NaN                     NaN
# 3                                                NaN                     NaN
# 4  {'license': 451, 'license_name': 'CC0 1.0 Univ...  [Sarracenia catesbaei]

# %%
df['lat'] = df['origin_location'].apply(lambda x: x['latitude'])
df['long'] = df['origin_location'].apply(lambda x: x['longitude'])
