# %%
import pandas as pd
import awswrangler as wr
import streamlit as st

# %%
plant_data = wr.athena.read_sql_query(
    sql='select plant_name as "Plant names",avg(average_temperature) as "Avg Temp",avg(average_soil_moisture) as "Avg Soil moisture",avg(number_of_times_watered) as "Avg No. of Times Watered" from c19_seljkfcq_project group by plant_name;', database="c19-m3y-db",)
df = pd.DataFrame(plant_data)
df
# Out:
#                       plant names  avg temp  avg soil moisture  \
# 0                    Wollemi pine      15.0              29.56
# 1           Asclepias Curassavica      18.0              32.19
# 2                       Anthurium      14.0              30.27
# 3                          Croton      15.0              33.68
# 4           Schefflera Arboricola      16.0              30.45
# 5              Monstera Deliciosa      16.0              36.64
# 6            Saintpaulia Ionantha      15.0              29.48
# 7               Epipremnum Aureum      15.0              34.91
# 8                      Gaillardia      14.0              32.11
# 9                   Venus flytrap      14.0              26.70
# 10             Rafflesia arnoldii      15.0              33.14
# 11               Black bat flower      16.0              35.83
# 12               Bird of paradise      16.0              30.98
# 13            Colocasia Esculenta      15.0              31.79
# 14          Cuphea ‘David Verity’      15.0              34.93
# 15                Ipomoea Batatas      15.0              28.81
# 16               Salvia Splendens      15.0              32.89
# 17            Cordyline Fruticosa      16.0              31.61
# 18          Dieffenbachia Seguine      15.0              33.10
# 19                 Ficus Elastica      16.0              32.46
# 20           Aglaonema Commutatum      13.0              33.22
# 21             Tacca Integrifolia      13.0              32.86
# 22                      Amaryllis      16.0              37.06
# 23            Medinilla Magnifica      17.0              30.84
# 24         Zamioculcas Zamiifolia      14.0              34.30
# 25                Canna ‘Striata’      14.0              36.07
# 26                  Corpse flower      14.0              37.55
# 27                  Pitcher plant      16.0              32.91
# 28                         Cactus      14.0              35.58
# 29  Manihot Esculenta ‘Variegata’      12.0              36.72
# 30                          Ficus      14.0              36.37
# 31                     Palm Trees      14.0              34.83
# 32                  Spathiphyllum      13.0              35.32
# 33                      Aloe Vera      17.0              32.64
# 34        Philodendron Hederaceum      16.0              32.57
# 35               Caladium Bicolor      15.0              35.25
# 36           Chlorophytum Comosum      13.0              36.49
# 37                    Dragon tree      13.0              33.86
# 38           Brugmansia X Candida      15.0              24.73
# 39          Euphorbia Cotinifolia      15.0               0.36
# 40                    Musa Basjoo      14.0              35.28
# 41        Sansevieria Trifasciata      17.0              33.94
# 42             Psychopsis Papilio      17.0              34.04
# 43         Araucaria Heterophylla      15.0              34.01
# 44                        Begonia      17.0              11.55
# 45      Calliandra Haematocephala      12.0               4.54
# 46                 Crassula Ovata      17.0              32.96
#
#     avg no. of times watered
# 0                        1.0
# 1                        1.0
# 2                        1.0
# 3                        1.0
# 4                        1.0
# 5                        1.0
# 6                        1.0
# 7                        1.0
# 8                        1.0
# 9                        1.0
# 10                       1.0
# 11                       1.0
# 12                       1.0
# 13                       1.0
# 14                       1.0
# 15                       1.0
# 16                       1.0
# 17                       1.0
# 18                       1.0
# 19                       1.0
# 20                       1.0
# 21                       1.0
# 22                       1.0
# 23                       1.0
# 24                       1.0
# 25                       1.0
# 26                       1.0
# 27                       1.0
# 28                       1.0
# 29                       1.0
# 30                       1.0
# 31                       1.0
# 32                       1.0
# 33                       1.0
# 34                       1.0
# 35                       1.0
# 36                       1.0
# 37                       1.0
# 38                       1.0
# 39                       1.0
# 40                       1.0
# 41                       1.0
# 42                       1.0
# 43                       1.0
# 44                       1.0
# 45                       1.0
# 46                       1.0

# %%
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 2
#       1 df = df[['plant_name', 'average_temperature','average_soil_moisture','number_of_times_watered']]
# ----> 2 df = df.groupby('plant_name').sum()
#       4 df
#
# File ~/Documents/seljkfcq-Week-13-Group-Project/.venv/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:1364, in GroupBy.__getattr__(self, attr)
#    1361 if attr in self.obj:
#    1362     return self[attr]
# -> 1364 raise AttributeError(
#    1365     f"'{type(self).__name__}' object has no attribute '{attr}'"
#    1366 )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'groupby'
