# %%
from os import environ as ENV
from dotenv import load_dotenv
import datetime

import streamlit as st
import pyodbc
import pandas as pd
import altair as alt
alt.data_transformers.enable("vegafusion")
# Out:
# DataTransformerRegistry.enable('vegafusion')

# %%
def get_db_connection() -> pyodbc.Connection:
    """Returns a connection to database."""

    load_dotenv()
    conn_str = (f"DRIVER={{{ENV['DB_DRIVER']}}};SERVER={ENV['DB_HOST']};"
                f"PORT={ENV['DB_PORT']};DATABASE={ENV['DB_NAME']};"
                f"UID={ENV['DB_USER']};PWD={ENV['DB_PASSWORD']};Encrypt=no;")

    conn = pyodbc.connect(conn_str)

    return conn


def load_data() -> pd.DataFrame:
    """ Pulls all the transaction data from the S3 bucket. """
    conn = get_db_connection()

    query = """
    SELECT
        pr.*, p.*, c.*
    FROM
        gamma.plant_reading pr
    LEFT JOIN
        gamma.plant p
    ON pr.plant_id = p.plant_id
    LEFT JOIN
        gamma.city c
    ON p.city_id = c.city_id;
    """

    df_recordings = pd.read_sql(query, conn)
    df_recordings.set_index("reading_id")
    return df_recordings

# %%
load_dotenv()
data = load_data()
data
# Out:
# /var/folders/yx/2vvnk19j32g5_ydz9hxjpgxc0000gp/T/ipykernel_57997/1118687527.py:31: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_recordings = pd.read_sql(query, conn)
#       reading_id  plant_id  botanist_id  temperature        last_watered  \
# 0              1         1            1           14 2025-09-25 13:51:41
# 1              2         2            2           14 2025-09-25 14:58:34
# 2              3         3            3           80 2025-09-25 13:58:19
# 3              4         4            4           16 2025-09-25 14:56:07
# 4              5         5            5           16 2025-09-25 13:57:08
# ...          ...       ...          ...          ...                 ...
# 7963        7964        41           42           18 2025-09-25 13:08:03
# 7964        7965        42           43           12 2025-09-25 14:50:57
# 7965        7966        43           44           15 2025-09-25 14:09:29
# 7966        7967        47           48           17 2025-09-25 14:08:03
# 7967        7968        44           45           15 2025-09-25 14:30:25
#
#       soil_moisture         recording_taken  plant_id  \
# 0             32.97 2025-09-26 09:28:06.098         1
# 1             34.15 2025-09-26 09:28:04.689         2
# 2             35.61 2025-09-26 09:28:05.186         3
# 3             36.58 2025-09-26 09:28:06.053         4
# 4             29.81 2025-09-26 09:28:05.664         5
# ...             ...                     ...       ...
# 7963          17.79 2025-09-26 12:20:05.321        41
# 7964         -10.50 2025-09-26 12:20:05.281        42
# 7965          26.55 2025-09-26 12:20:05.193        43
# 7966          22.63 2025-09-26 12:20:04.690        47
# 7967          25.02 2025-09-26 12:20:05.299        44
#
#                      plant_name    lat    lang  city_id  \
# 0                 Venus flytrap  43.74  -11.51        1
# 1                 Corpse flower  47.84  -48.71        2
# 2            Rafflesia arnoldii -25.49  -36.13        3
# 3              Black bat flower  63.37   46.40        4
# 4                 Pitcher plant  82.89    0.63        5
# ...                         ...    ...     ...      ...
# 7963        Medinilla Magnifica -34.19  -78.70       42
# 7964  Calliandra Haematocephala  83.92 -148.55       43
# 7965     Zamioculcas Zamiifolia -82.18  -72.49       44
# 7966             Crassula Ovata  15.80  148.99       48
# 7967          Epipremnum Aureum -62.63   18.62       45
#
#                   scientific_name  city_id          city_name  \
# 0                            None        1          Stammside
# 1                            None        2           Floshire
# 2                            None        3          Dale City
# 3                            None        4       West Tedboro
# 4          'Sarracenia catesbaei'        5      North Felicia
# ...                           ...      ...                ...
# 7963        'Medinilla magnifica'       42       Kathrynville
# 7964  'Calliandra haematocephala'       43          Gavinstad
# 7965     'Zamioculcas zamiifolia'       44  Lake Norbertstead
# 7966             'Crassula ovata'       48           Ginaberg
# 7967          'Epipremnum aureum'       45          Joanyland
#
#                  state_name
# 0                   Albania
# 1            American Samoa
# 2                Mozambique
# 3                    Taiwan
# 4     Saint Kitts and Nevis
# ...                     ...
# 7963                  Macao
# 7964                 Jersey
# 7965              Greenland
# 7966                   Togo
# 7967    Antigua and Barbuda
#
# [7968 rows x 16 columns]

# %%
last_watered_df = data[['last_watered', 'plant_name']]
last_watered_df
# Out:
#             last_watered                 plant_name
# 0    2025-09-25 13:51:41              Venus flytrap
# 1    2025-09-25 14:58:34              Corpse flower
# 2    2025-09-25 13:58:19         Rafflesia arnoldii
# 3    2025-09-25 14:56:07           Black bat flower
# 4    2025-09-25 13:57:08              Pitcher plant
# ...                  ...                        ...
# 7963 2025-09-25 13:08:03        Medinilla Magnifica
# 7964 2025-09-25 14:50:57  Calliandra Haematocephala
# 7965 2025-09-25 14:09:29     Zamioculcas Zamiifolia
# 7966 2025-09-25 14:08:03             Crassula Ovata
# 7967 2025-09-25 14:30:25          Epipremnum Aureum
#
# [7968 rows x 2 columns]

# %%
data.sort_values(by=['plant_name', 'last_watered'])
# Out:
#       reading_id  plant_id  botanist_id  temperature        last_watered  \
# 31            32        32           33           12 2025-09-25 14:18:52
# 75            76        32           33           12 2025-09-25 14:18:52
# 122          123        32           33           12 2025-09-25 14:18:52
# 168          169        32           33           12 2025-09-25 14:18:52
# 214          215        32           33           12 2025-09-25 14:18:52
# ...          ...       ...          ...          ...                 ...
# 7780        7781        43           44           15 2025-09-25 14:09:29
# 7827        7828        43           44          115 2025-09-25 14:09:29
# 7872        7873        43           44           15 2025-09-25 14:09:29
# 7919        7920        43           44           15 2025-09-25 14:09:29
# 7965        7966        43           44           15 2025-09-25 14:09:29
#
#       soil_moisture         recording_taken  plant_id              plant_name  \
# 31            32.53 2025-09-26 09:28:04.944        32    Aglaonema Commutatum
# 75            35.14 2025-09-26 09:29:04.364        32    Aglaonema Commutatum
# 122           32.08 2025-09-26 09:30:05.028        32    Aglaonema Commutatum
# 168           35.15 2025-09-26 09:31:05.359        32    Aglaonema Commutatum
# 214           33.72 2025-09-26 09:32:04.767        32    Aglaonema Commutatum
# ...             ...                     ...       ...                     ...
# 7780          23.76 2025-09-26 12:16:05.249        43  Zamioculcas Zamiifolia
# 7827          22.89 2025-09-26 12:17:05.340        43  Zamioculcas Zamiifolia
# 7872          27.00 2025-09-26 12:18:04.539        43  Zamioculcas Zamiifolia
# 7919          22.25 2025-09-26 12:19:05.542        43  Zamioculcas Zamiifolia
# 7965          26.55 2025-09-26 12:20:05.193        43  Zamioculcas Zamiifolia
#
#         lat   lang  city_id           scientific_name  city_id  \
# 31   -59.67  22.17       33    'Aglaonema commutatum'       33
# 75   -59.67  22.17       33    'Aglaonema commutatum'       33
# 122  -59.67  22.17       33    'Aglaonema commutatum'       33
# 168  -59.67  22.17       33    'Aglaonema commutatum'       33
# 214  -59.67  22.17       33    'Aglaonema commutatum'       33
# ...     ...    ...      ...                       ...      ...
# 7780 -82.18 -72.49       44  'Zamioculcas zamiifolia'       44
# 7827 -82.18 -72.49       44  'Zamioculcas zamiifolia'       44
# 7872 -82.18 -72.49       44  'Zamioculcas zamiifolia'       44
# 7919 -82.18 -72.49       44  'Zamioculcas zamiifolia'       44
# 7965 -82.18 -72.49       44  'Zamioculcas zamiifolia'       44
#
#               city_name      state_name
# 31           New Danika  Western Sahara
# 75           New Danika  Western Sahara
# 122          New Danika  Western Sahara
# 168          New Danika  Western Sahara
# 214          New Danika  Western Sahara
# ...                 ...             ...
# 7780  Lake Norbertstead       Greenland
# 7827  Lake Norbertstead       Greenland
# 7872  Lake Norbertstead       Greenland
# 7919  Lake Norbertstead       Greenland
# 7965  Lake Norbertstead       Greenland
#
# [7968 rows x 16 columns]

# %%
last_watered_df = data[['plant_name','last_watered']]
last_watered_df
# Out:
#                      plant_name        last_watered
# 0                 Venus flytrap 2025-09-25 13:51:41
# 1                 Corpse flower 2025-09-25 14:58:34
# 2            Rafflesia arnoldii 2025-09-25 13:58:19
# 3              Black bat flower 2025-09-25 14:56:07
# 4                 Pitcher plant 2025-09-25 13:57:08
# ...                         ...                 ...
# 7963        Medinilla Magnifica 2025-09-25 13:08:03
# 7964  Calliandra Haematocephala 2025-09-25 14:50:57
# 7965     Zamioculcas Zamiifolia 2025-09-25 14:09:29
# 7966             Crassula Ovata 2025-09-25 14:08:03
# 7967          Epipremnum Aureum 2025-09-25 14:30:25
#
# [7968 rows x 2 columns]

# %%
last_watered_df = last_watered_df.drop_duplicates()
last_watered_df
# Out:
#                        plant_name        last_watered
# 0                   Venus flytrap 2025-09-25 13:51:41
# 1                   Corpse flower 2025-09-25 14:58:34
# 2              Rafflesia arnoldii 2025-09-25 13:58:19
# 3                Black bat flower 2025-09-25 14:56:07
# 4                   Pitcher plant 2025-09-25 13:57:08
# 5                    Wollemi pine 2025-09-25 13:03:31
# 6                Bird of paradise 2025-09-25 13:33:20
# 7                          Cactus 2025-09-25 14:19:58
# 8                     Dragon tree 2025-09-25 14:15:42
# 9           Asclepias Curassavica 2025-09-25 13:32:16
# 10           Brugmansia X Candida 2025-09-25 13:34:25
# 11                Canna ‘Striata’ 2025-09-25 14:46:28
# 12            Colocasia Esculenta 2025-09-25 13:28:35
# 13          Cuphea ‘David Verity’ 2025-09-25 14:17:16
# 14          Euphorbia Cotinifolia 2025-09-25 14:02:07
# 15                Ipomoea Batatas 2025-09-25 13:10:19
# 16  Manihot Esculenta ‘Variegata’ 2025-09-25 14:39:50
# 17                    Musa Basjoo 2025-09-25 14:41:59
# 18               Salvia Splendens 2025-09-25 14:11:20
# 19                      Anthurium 2025-09-25 13:12:41
# 20            Cordyline Fruticosa 2025-09-25 13:02:45
# 21                          Ficus 2025-09-25 14:47:33
# 22                     Palm Trees 2025-09-25 14:35:22
# 23          Dieffenbachia Seguine 2025-09-25 14:10:30
# 24                  Spathiphyllum 2025-09-25 14:33:40
# 25                         Croton 2025-09-25 13:51:21
# 26                      Aloe Vera 2025-09-25 13:49:02
# 27                 Ficus Elastica 2025-09-25 13:33:30
# 28        Sansevieria Trifasciata 2025-09-25 14:14:04
# 29        Philodendron Hederaceum 2025-09-25 13:40:10
# 30          Schefflera Arboricola 2025-09-25 13:15:17
# 31           Aglaonema Commutatum 2025-09-25 14:18:52
# 32             Tacca Integrifolia 2025-09-25 13:52:51
# 33             Psychopsis Papilio 2025-09-25 14:12:01
# 34                     Gaillardia 2025-09-25 13:29:36
# 35                      Amaryllis 2025-09-25 14:58:06
# 36               Caladium Bicolor 2025-09-25 14:30:02
# 37           Chlorophytum Comosum 2025-09-25 14:38:45
# 38         Araucaria Heterophylla 2025-09-25 14:20:23
# 39                        Begonia 2025-09-25 13:32:05
# 40            Medinilla Magnifica 2025-09-25 13:08:03
# 41      Calliandra Haematocephala 2025-09-25 14:50:57
# 42         Zamioculcas Zamiifolia 2025-09-25 14:09:29
# 43              Epipremnum Aureum 2025-09-25 14:30:25
# 76             Monstera Deliciosa 2025-09-25 14:55:08
# 79           Saintpaulia Ionantha 2025-09-25 13:19:28
# 89                 Crassula Ovata 2025-09-25 14:08:03

# %%
def format_timedelta(delta: datetime.timedelta) -> str:
    """ Formats timedelta into a more readable format. """
    seconds_in_day = 86400
    seconds_in_hour = 3600
    seconds_in_minute = 60

    seconds = int(delta.total_seconds())

    days = seconds // seconds_in_day
    hours = (seconds % seconds_in_day) // seconds_in_hour
    minutes = (seconds % seconds_in_hour) // seconds_in_minute

    return f'{days} days, {hours} hours, {minutes} minutes'

# %%
now = datetime.datetime.now()
last_watered_df['hours_since_watered'] = (now - last_watered_df['last_watered']).dt.total_seconds() / 3600
last_watered_df['time_since_watered_formatted'] = (
    now - last_watered_df['last_watered']).apply(format_timedelta)
last_watered_df
# Out:
# /var/folders/yx/2vvnk19j32g5_ydz9hxjpgxc0000gp/T/ipykernel_57997/3715007286.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   last_watered_df['hours_since_watered'] = (now - last_watered_df['last_watered']).dt.total_seconds() / 3600
# /var/folders/yx/2vvnk19j32g5_ydz9hxjpgxc0000gp/T/ipykernel_57997/3715007286.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   last_watered_df['time_since_watered_formatted'] = (
#                        plant_name        last_watered  hours_since_watered  \
# 0                   Venus flytrap 2025-09-25 13:51:41            23.487224
# 1                   Corpse flower 2025-09-25 14:58:34            22.372502
# 2              Rafflesia arnoldii 2025-09-25 13:58:19            23.376669
# 3                Black bat flower 2025-09-25 14:56:07            22.413335
# 4                   Pitcher plant 2025-09-25 13:57:08            23.396391
# 5                    Wollemi pine 2025-09-25 13:03:31            24.290002
# 6                Bird of paradise 2025-09-25 13:33:20            23.793058
# 7                          Cactus 2025-09-25 14:19:58            23.015835
# 8                     Dragon tree 2025-09-25 14:15:42            23.086947
# 9           Asclepias Curassavica 2025-09-25 13:32:16            23.810835
# 10           Brugmansia X Candida 2025-09-25 13:34:25            23.775002
# 11                Canna ‘Striata’ 2025-09-25 14:46:28            22.574169
# 12            Colocasia Esculenta 2025-09-25 13:28:35            23.872224
# 13          Cuphea ‘David Verity’ 2025-09-25 14:17:16            23.060835
# 14          Euphorbia Cotinifolia 2025-09-25 14:02:07            23.313335
# 15                Ipomoea Batatas 2025-09-25 13:10:19            24.176669
# 16  Manihot Esculenta ‘Variegata’ 2025-09-25 14:39:50            22.684724
# 17                    Musa Basjoo 2025-09-25 14:41:59            22.648891
# 18               Salvia Splendens 2025-09-25 14:11:20            23.159724
# 19                      Anthurium 2025-09-25 13:12:41            24.137224
# 20            Cordyline Fruticosa 2025-09-25 13:02:45            24.302780
# 21                          Ficus 2025-09-25 14:47:33            22.556113
# 22                     Palm Trees 2025-09-25 14:35:22            22.759169
# 23          Dieffenbachia Seguine 2025-09-25 14:10:30            23.173613
# 24                  Spathiphyllum 2025-09-25 14:33:40            22.787502
# 25                         Croton 2025-09-25 13:51:21            23.492780
# 26                      Aloe Vera 2025-09-25 13:49:02            23.531391
# 27                 Ficus Elastica 2025-09-25 13:33:30            23.790280
# 28        Sansevieria Trifasciata 2025-09-25 14:14:04            23.114169
# 29        Philodendron Hederaceum 2025-09-25 13:40:10            23.679169
# 30          Schefflera Arboricola 2025-09-25 13:15:17            24.093891
# 31           Aglaonema Commutatum 2025-09-25 14:18:52            23.034169
# 32             Tacca Integrifolia 2025-09-25 13:52:51            23.467780
# 33             Psychopsis Papilio 2025-09-25 14:12:01            23.148335
# 34                     Gaillardia 2025-09-25 13:29:36            23.855280
# 35                      Amaryllis 2025-09-25 14:58:06            22.380280
# 36               Caladium Bicolor 2025-09-25 14:30:02            22.848058
# 37           Chlorophytum Comosum 2025-09-25 14:38:45            22.702780
# 38         Araucaria Heterophylla 2025-09-25 14:20:23            23.008891
# 39                        Begonia 2025-09-25 13:32:05            23.813891
# 40            Medinilla Magnifica 2025-09-25 13:08:03            24.214447
# 41      Calliandra Haematocephala 2025-09-25 14:50:57            22.499447
# 42         Zamioculcas Zamiifolia 2025-09-25 14:09:29            23.190558
# 43              Epipremnum Aureum 2025-09-25 14:30:25            22.841669
# 76             Monstera Deliciosa 2025-09-25 14:55:08            22.429724
# 79           Saintpaulia Ionantha 2025-09-25 13:19:28            24.024169
# 89                 Crassula Ovata 2025-09-25 14:08:03            23.214447
#
#     time_since_watered_formatted
# 0   0 days, 23 hours, 29 minutes
# 1   0 days, 22 hours, 22 minutes
# 2   0 days, 23 hours, 22 minutes
# 3   0 days, 22 hours, 24 minutes
# 4   0 days, 23 hours, 23 minutes
# 5    1 days, 0 hours, 17 minutes
# 6   0 days, 23 hours, 47 minutes
# 7    0 days, 23 hours, 0 minutes
# 8    0 days, 23 hours, 5 minutes
# 9   0 days, 23 hours, 48 minutes
# 10  0 days, 23 hours, 46 minutes
# 11  0 days, 22 hours, 34 minutes
# 12  0 days, 23 hours, 52 minutes
# 13   0 days, 23 hours, 3 minutes
# 14  0 days, 23 hours, 18 minutes
# 15   1 days, 0 hours, 10 minutes
# 16  0 days, 22 hours, 41 minutes
# 17  0 days, 22 hours, 38 minutes
# 18   0 days, 23 hours, 9 minutes
# 19    1 days, 0 hours, 8 minutes
# 20   1 days, 0 hours, 18 minutes
# 21  0 days, 22 hours, 33 minutes
# 22  0 days, 22 hours, 45 minutes
# 23  0 days, 23 hours, 10 minutes
# 24  0 days, 22 hours, 47 minutes
# 25  0 days, 23 hours, 29 minutes
# 26  0 days, 23 hours, 31 minutes
# 27  0 days, 23 hours, 47 minutes
# 28   0 days, 23 hours, 6 minutes
# 29  0 days, 23 hours, 40 minutes
# 30    1 days, 0 hours, 5 minutes
# 31   0 days, 23 hours, 2 minutes
# 32  0 days, 23 hours, 28 minutes
# 33   0 days, 23 hours, 8 minutes
# 34  0 days, 23 hours, 51 minutes
# 35  0 days, 22 hours, 22 minutes
# 36  0 days, 22 hours, 50 minutes
# 37  0 days, 22 hours, 42 minutes
# 38   0 days, 23 hours, 0 minutes
# 39  0 days, 23 hours, 48 minutes
# 40   1 days, 0 hours, 12 minutes
# 41  0 days, 22 hours, 29 minutes
# 42  0 days, 23 hours, 11 minutes
# 43  0 days, 22 hours, 50 minutes
# 76  0 days, 22 hours, 25 minutes
# 79    1 days, 0 hours, 1 minutes
# 89  0 days, 23 hours, 12 minutes

# %%
alt.Chart(last_watered_df, title='Time since each plant was watered').mark_bar().encode(
    y=alt.Y('plant_name', title='Plant Name',
            axis=alt.Axis(labelLimit=200), sort='-x'),
    x=alt.X('hours_since_watered', title='Hours since watered'),
    tooltip=[alt.Tooltip('time_since_watered_formatted', title='Time since plant was watered')]
)
# Out:
# alt.Chart(...)
